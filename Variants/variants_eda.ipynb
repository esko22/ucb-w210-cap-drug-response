# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
variants_df = pd.read_csv('../data/WES_variants.csv')
variants_df.head()
# Out:
#       SAMPLE  COSMIC_ID Cancer Type  Gene       Transcript       cDNA  \
# 0  KARPAS-45     907272         ALL  A1BG  ENST00000263100   c.842A>G
# 1     Jurkat     998184         ALL  A1BG  ENST00000263100   c.589G>A
# 2  KARPAS-45     907272         ALL  A1BG  ENST00000263100   c.571G>A
# 3     HT-115     907289   COAD/READ  A1BG  ENST00000263100  c.1456G>A
# 4       KM12     905989   COAD/READ  A1BG  ENST00000263100   c.770C>A
#
#         AA Classification Gene_list Recurrence Filter  Subs  Truncating  \
# 0  p.Y281C       missense       NaN               NaN   NaN         NaN
# 1  p.A197T       missense       NaN               NaN   NaN         NaN
# 2  p.A191T       missense       NaN               NaN   2.0         NaN
# 3  p.D486N       missense       NaN               NaN   NaN         NaN
# 4  p.T257N       missense       NaN               NaN   NaN         NaN
#
#    inframe
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
variants_df.count()
# Out:
# SAMPLE               486243
# COSMIC_ID            486243
# Cancer Type          409611
# Gene                 486243
# Transcript           486243
# cDNA                 486243
# AA                   486243
# Classification       486243
# Gene_list             24214
# Recurrence Filter     29214
# Subs                  52568
# Truncating            65745
# inframe                 441
# dtype: int64

# %%
variants_by_cell_line_df = variants_df[variants_df['COSMIC_ID'] == 683665]

# %%
variants_by_cell_line_df.head(100)
# Out:
#         SAMPLE  COSMIC_ID Cancer Type       Gene           Transcript  \
# 738     MC-CAR     683665          MM       ABAT      ENST00000396600
# 1924    MC-CAR     683665          MM      ABCA8      ENST00000269080
# 3573    MC-CAR     683665          MM      ABCG5      ENST00000260645
# 6260    MC-CAR     683665          MM      ACAP1      ENST00000158762
# 12007   MC-CAR     683665          MM      ADCY4      ENST00000310677
# 12933   MC-CAR     683665          MM    ADORA2B      ENST00000304222
# 14793   MC-CAR     683665          MM    AGTPBP1      ENST00000376083
# 15946   MC-CAR     683665          MM      AIFM2      ENST00000307864
# 20390   MC-CAR     683665          MM      AMPD3      ENST00000396554
# 20729   MC-CAR     683665          MM     ANAPC5          NM_016237.3
# 21558   MC-CAR     683665          MM      ANKAR      ENST00000520309
# 24324   MC-CAR     683665          MM       ANO3      ENST00000256737
# 26854   MC-CAR     683665          MM       APOB      ENST00000233242
# 33042   MC-CAR     683665          MM       ASB8      ENST00000317697
# 35859   MC-CAR     683665          MM     ATP10B      ENST00000327245
# 37808   MC-CAR     683665          MM     ATP8B1      ENST00000283684
# 39764   MC-CAR     683665          MM   B4GALNT2      ENST00000300404
# 44426   MC-CAR     683665          MM       BMP5      ENST00000370830
# 49165   MC-CAR     683665          MM   C11orf45      ENST00000310799
# 50774   MC-CAR     683665          MM  C14orf101      ENST00000261556
# 51648   MC-CAR     683665          MM   C15orf33      ENST00000299338
# 52123   MC-CAR     683665          MM   C16orf62      ENST00000438132
# 52546   MC-CAR     683665          MM   C17orf47      ENST00000321691
# 55117   MC-CAR     683665          MM     C1orf9      ENST00000263688
# 57608   MC-CAR     683665          MM    C2orf84      ENST00000415196
# 59344   MC-CAR     683665          MM    C5orf42      ENST00000425232
# 59619   MC-CAR     683665          MM         C6      ENST00000263413
# 59620   MC-CAR     683665          MM         C6      ENST00000263413
# 59917   MC-CAR     683665          MM   C6orf163      ENST00000388923
# 61868   MC-CAR     683665          MM   C9orf125          NM_032342.1
# ...        ...        ...         ...        ...                  ...
# 151553  MC-CAR     683665          MM      FATE1      ENST00000370350
# 156807  MC-CAR     683665          MM      FKBP4      ENST00000001008
# 158060  MC-CAR     683665          MM       FLNB      ENST00000295956
# 158209  MC-CAR     683665          MM       FLNC      ENST00000325888
# 159621  MC-CAR     683665          MM     FNDC3A      ENST00000492622
# 167114  MC-CAR     683665          MM       GBP1      ENST00000370473
# 168360  MC-CAR     683665          MM     GEMIN4          NM_015721.1
# 175552  MC-CAR     683665          MM     GPR149      ENST00000389740
# 177276  MC-CAR     683665          MM    GPRASP1      ENST00000415986
# 179862  MC-CAR     683665          MM       GRM7      ENST00000389335
# 184344  MC-CAR     683665          MM    HEATR7A      ENST00000528919
# 190032  MC-CAR     683665          MM    HNRNPH2      ENST00000316594
# 191490  MC-CAR     683665          MM       HRAS      ENST00000397596
# 194276  MC-CAR     683665          MM      HYDIN  ENST00000316490_v65
# 198348  MC-CAR     683665          MM     IL18BP      ENST00000337131
# 199769  MC-CAR     683665          MM      IMPG1      ENST00000369950
# 200308  MC-CAR     683665          MM     INO80D      ENST00000403263
# 200693  MC-CAR     683665          MM     INPPL1          NM_001567.2
# 202299  MC-CAR     683665          MM     IQGAP3      ENST00000361170
# 204660  MC-CAR     683665          MM      ITGB3      ENST00000262017
# 206179  MC-CAR     683665          MM     IZUMO4      ENST00000300960
# 208302  MC-CAR     683665          MM     KCNAB1      ENST00000490337
# 213431  MC-CAR     683665          MM   KIAA0649      ENST00000356818
# 215348  MC-CAR     683665          MM   KIAA1404      ENST00000396105
# 216211  MC-CAR     683665          MM   KIAA1609      ENST00000343629
# 223013  MC-CAR     683665          MM      KRT31      ENST00000251645
# 224891  MC-CAR     683665          MM   KRTAP9L2      ENST00000391355
# 227388  MC-CAR     683665          MM      LASS6      ENST00000305747
# 227892  MC-CAR     683665          MM      LCMT2      ENST00000305641
# 229353  MC-CAR     683665          MM       LGR6      ENST00000367278
#
#                cDNA          AA Classification         Gene_list  \
# 738         c.26G>A       p.R9H       missense               NaN
# 1924    c.3309+5G>T         p.?     ess_splice               NaN
# 3573      c.1436C>T     p.T479I       missense               NaN
# 6260      c.2206G>A     p.D736N       missense               NaN
# 12007     c.2804C>G     p.T935R       missense               NaN
# 12933      c.824C>A     p.A275D       missense               NaN
# 14793     c.1758C>A     p.D586E       missense               NaN
# 15946     c.1057C>A     p.L353M       missense               NaN
# 20390      c.729C>G     p.N243K       missense               NaN
# 20729      c.132G>A      p.M44I       missense               NaN
# 21558    c.1458delG  p.K486fs*8     frameshift               NaN
# 24324      c.307T>G     p.C103G       missense               NaN
# 26854     c.4553C>T    p.S1518F       missense               NaN
# 33042      c.779G>C     p.R260P       missense               NaN
# 35859      c.997G>A     p.V333I       missense               NaN
# 37808     c.2632G>A     p.D878N       missense               NaN
# 39764     c.1417G>A     p.V473I       missense               NaN
# 44426     c.1069G>A     p.E357K       missense               NaN
# 49165      c.284C>G      p.S95C       missense               NaN
# 50774     c.1846C>G     p.Q616E       missense               NaN
# 51648       c.73A>G      p.S25G       missense               NaN
# 52123     c.1208A>C     p.E403A       missense               NaN
# 52546      c.728T>G     p.V243G       missense               NaN
# 55117     c.1684C>T     p.H562Y       missense               NaN
# 57608      c.275G>A      p.R92H       missense               NaN
# 59344     c.9532G>A    p.E3178K       missense               NaN
# 59619     c.1466C>T     p.P489L       missense               NaN
# 59620     c.1465C>T     p.P489S       missense               NaN
# 59917      c.664G>A     p.G222S       missense               NaN
# 61868     c.196delC   p.L66fs*5     frameshift               NaN
# ...             ...         ...            ...               ...
# 151553     c.134G>T      p.R45L       missense               NaN
# 156807    c.1232A>G     p.Y411C       missense               NaN
# 158060    c.3643C>T    p.H1215Y       missense               NaN
# 158209    c.1645A>G     p.I549V       missense               NaN
# 159621     c.225C>G      p.I75M       missense               NaN
# 167114    c.1054G>T     p.E352*       nonsense               NaN
# 168360    c.1853C>T     p.P618L       missense               NaN
# 175552    c.1977C>G     p.N659K       missense               NaN
# 177276     c.775A>C     p.K259Q       missense               NaN
# 179862    c.2429G>A     p.G810D       missense               NaN
# 184344      c.64C>T      p.P22S       missense               NaN
# 190032    c.1291A>G     p.S431G       missense               NaN
# 191490     c.182A>G      p.Q61R       missense  IntOGen pipeline
# 194276    c.3065G>A    p.C1022Y       missense               NaN
# 198348     c.554C>A     p.S185Y       missense               NaN
# 199769      c.22G>C       p.A8P       missense               NaN
# 200308     c.793C>T     p.P265S       missense               NaN
# 200693    c.1872C>A     p.S624R       missense  IntOGen pipeline
# 202299    c.2556T>G     p.S852R       missense               NaN
# 204660     c.901G>A     p.V301I       missense               NaN
# 206179     c.206C>G      p.P69R       missense               NaN
# 208302    c.1193A>G     p.H398R       missense               NaN
# 213431    c.1220C>A     p.T407K       missense               NaN
# 215348    c.5366A>G    p.Y1789C       missense               NaN
# 216211     c.481C>T     p.R161W       missense               NaN
# 223013     c.842C>T     p.A281V       missense               NaN
# 224891      c.86T>A      p.V29E       missense               NaN
# 227388      c.71T>G      p.L24R       missense               NaN
# 227892    c.1427C>G     p.T476S       missense               NaN
# 229353   c.716+5G>A         p.?     ess_splice               NaN
#
#        Recurrence Filter  Subs  Truncating  inframe
# 738                  NaN   NaN         NaN      NaN
# 1924                 Yes   NaN        28.0      NaN
# 3573                 NaN   NaN         NaN      NaN
# 6260                 NaN   NaN         NaN      NaN
# 12007                NaN   NaN         NaN      NaN
# 12933                NaN   NaN         NaN      NaN
# 14793                NaN   NaN         NaN      NaN
# 15946                NaN   NaN         NaN      NaN
# 20390                NaN   NaN         NaN      NaN
# 20729                NaN   NaN         NaN      NaN
# 21558                Yes   NaN        15.0      NaN
# 24324                NaN   NaN         NaN      NaN
# 26854                NaN   NaN         NaN      NaN
# 33042                NaN   NaN         NaN      NaN
# 35859                NaN   NaN         NaN      NaN
# 37808                NaN   1.0         NaN      NaN
# 39764                NaN   NaN         NaN      NaN
# 44426                NaN   NaN         NaN      NaN
# 49165                NaN   NaN         NaN      NaN
# 50774                NaN   NaN         NaN      NaN
# 51648                NaN   NaN         NaN      NaN
# 52123                NaN   NaN         NaN      NaN
# 52546                NaN   NaN         NaN      NaN
# 55117                NaN   NaN         NaN      NaN
# 57608                NaN   NaN         NaN      NaN
# 59344                NaN   1.0         NaN      NaN
# 59619                NaN   NaN         NaN      NaN
# 59620                NaN   NaN         NaN      NaN
# 59917                NaN   NaN         NaN      NaN
# 61868                NaN   NaN         5.0      NaN
# ...                  ...   ...         ...      ...
# 151553               NaN   NaN         NaN      NaN
# 156807               NaN   NaN         NaN      NaN
# 158060               NaN   NaN         NaN      NaN
# 158209               NaN   NaN         NaN      NaN
# 159621               NaN   NaN         NaN      NaN
# 167114               NaN   NaN         4.0      NaN
# 168360               NaN   NaN         NaN      NaN
# 175552               NaN   NaN         NaN      NaN
# 177276               NaN   NaN         NaN      NaN
# 179862               NaN   NaN         NaN      NaN
# 184344               NaN   NaN         NaN      NaN
# 190032               NaN   NaN         NaN      NaN
# 191490               Yes  14.0         NaN      NaN
# 194276               NaN   NaN         NaN      NaN
# 198348               Yes   3.0         NaN      NaN
# 199769               NaN   NaN         NaN      NaN
# 200308               NaN   NaN         NaN      NaN
# 200693               NaN   NaN         NaN      NaN
# 202299               NaN   NaN         NaN      NaN
# 204660               NaN   1.0         NaN      NaN
# 206179               NaN   NaN         NaN      NaN
# 208302               NaN   NaN         NaN      NaN
# 213431               NaN   NaN         NaN      NaN
# 215348               NaN   NaN         NaN      NaN
# 216211               NaN   NaN         NaN      NaN
# 223013               NaN   NaN         NaN      NaN
# 224891               NaN   NaN         NaN      NaN
# 227388               NaN   NaN         NaN      NaN
# 227892               NaN   NaN         NaN      NaN
# 229353               NaN   NaN         8.0      NaN
#
# [100 rows x 13 columns]

# %%
variants_by_cell_line_df.count()
# Out:
# SAMPLE               193
# COSMIC_ID            193
# Cancer Type          193
# Gene                 193
# Transcript           193
# cDNA                 193
# AA                   193
# Classification       193
# Gene_list              8
# Recurrence Filter     10
# Subs                  15
# Truncating            19
# inframe                0
# dtype: int64
