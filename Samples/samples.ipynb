# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
samples_df = pd.read_excel('../data/mmc2.xlsx', sheet_name=3)

# %%
samples_df.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  Table S1D - List primary tumour samples with d...
# 1         NaN                                         Patient id
# 2         NaN                                                NaN
# 3         NaN                                       TCGA-06-5411
# 4         NaN                                       TCGA-38-4631
#
#                   Unnamed: 2                      Unnamed: 3  \
# 0                        NaN                             NaN
# 1  Cancer Type\n(TCGA Label)  Available Data ? (Y)es or (N)o
# 2                        NaN    Whole Exome Sequencing (WES)
# 3                        GBM                               Y
# 4                       LUAD                               Y
#
#                       Unnamed: 4   Unnamed: 5    Unnamed: 6  \
# 0                            NaN          NaN           NaN
# 1                            NaN          NaN  Hypermutator
# ...

# %%
samples_df = samples_df[['Unnamed: 1','Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5']]

# %%
samples_df.head()
# Out:
#                                           Unnamed: 1  \
# 0  Table S1D - List primary tumour samples with d...
# 1                                         Patient id
# 2                                                NaN
# 3                                       TCGA-06-5411
# 4                                       TCGA-38-4631
#
#                   Unnamed: 2                      Unnamed: 3  \
# 0                        NaN                             NaN
# 1  Cancer Type\n(TCGA Label)  Available Data ? (Y)es or (N)o
# 2                        NaN    Whole Exome Sequencing (WES)
# 3                        GBM                               Y
# 4                       LUAD                               Y
#
#                       Unnamed: 4   Unnamed: 5
# 0                            NaN          NaN
# 1                            NaN          NaN
# 2  Copy Number Alterations (CNA)  Methylation
# 3                              Y            Y
# ...

# %%
samples_df = samples_df.drop(samples_df.index[0])

# %%
samples_df.head()
# Out:
#      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 3  TCGA-06-5411        GBM          Y          Y          Y
# 6  TCGA-A3-3358       KIRC          Y          Y          Y
# 7  TCGA-AA-3663  COAD/READ          Y          Y          Y
# 8  TCGA-AZ-4315  COAD/READ          Y          Y          Y
# 9  TCGA-CA-6717  COAD/READ          Y          Y          Y

# %%
samples_df.columns = ["PATIENT_ID","TCGA_LABEL","WES","CNA","METHYL"]

# %%
samples_df.head()
# Out:
#      PATIENT_ID TCGA_LABEL WES CNA METHYL
# 3  TCGA-06-5411        GBM   Y   Y      Y
# 6  TCGA-A3-3358       KIRC   Y   Y      Y
# 7  TCGA-AA-3663  COAD/READ   Y   Y      Y
# 8  TCGA-AZ-4315  COAD/READ   Y   Y      Y
# 9  TCGA-CA-6717  COAD/READ   Y   Y      Y

# %%
samples_df.head(100).to_json(orient='records', path_or_buf='samples_100.json')
